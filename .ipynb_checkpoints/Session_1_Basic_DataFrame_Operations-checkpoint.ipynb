# %% [markdown]
# # 22/04/25

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %% [markdown]
# ## Exploratory Data analysis(EDA):
#
# - we have 4 important packages or modules available
#
# - pandas
#
#     - Data Frame operations
#
# - numpy
#
#     - numerical opeations
#
# - matplotlib
#
#     - for plotting
#
# - seaborn
#
#     - for plotting

# %%
==============================EDA===================================
1) pandas : Data frame operations
2) numpy : math operations
3) matplotlib : plotting or graphs
4) seaborn : plotting or graphs
5) plotly : plotting or graphs
6) bokhe : plotting or graphs

====================== Machine learning ==========================
7) sickit-learn(sklean) : For ALL ML algorithms
8) stats : some statistical operations
    
====================== Deep learning ================================
9) Tensorflow : Deep learning models (Google)
10) keras : Deep learning models tensorflow as backend
11) pytorch : Deep learning models (Meta)
12) opencv : Image and Video opeartions
13) pillow : Image operations

=================== Object Detection models(Transfer learning)==================
14) Mobilenet : Deep learning packages
15) VGGnet : Deep learning packages
16) Resnet : Deep learning packages
17) Inceptionv3 : Deep learning packages
18) YOLO : Deep learning packages
    
====================== Natural Language process ===============================
19) NLTK : Natural Langauge Tool Kit
20) SpCy : Alternative to NLTK
21) Wordcloud : Text representation

======================= NLP word Embedding Models ==============================
22) Word2Vec : Google
23) GloVe : Stanford
24) Fasttext : Meta(Face book)

====================== ALLEN NLP (organization) ===========================
25) NLP applications : Pyspark as Backend In [ ]: In [ ]:

======================= Optical Character Recognition(OCR) ===============
Extract the text from the image
26) Tesseract
27) easyocr

=========================BERT=======================================
BERT: Bi directional Encoded Representations from Transformers
28) Transformers : Hugging face (Google)

==================== WebScrapping ===========================
29) SQLITE : Connect the Database using python
30) Selenium
31) Beautiful soup
32) Regex

===================== GenAI and LLM =============================
33) Langchain : To Connect all LLM models
34) GPT : OpenAI
35) Gemini : Google
36) Llama : Meta
37) Grok : XAi
38) BedRock : Amazon
39) Claude AI : Anthropic

=================== Agentic AI==================================
40) Langraph
41) CrewAI
42) Phidata
43) Autogen

==================== API creation==============================
44) Flask
45) FastAPI
46) Gradio
47) Django

===================== WebAppliaction ===========================
48) Streamlit

======================= Model deployment(MLops) ==============================
49) mlflow
50) Kubeflow

========================== Cloud AI =========================================
51) Azure Cognitive services
52) Azure ML Studio
53) GCP vertexAI
54) AWS Sagemaker
    
=============================== Extra ========================================
55) random
56) time
57) math
58) logging
59) warnings
60) date

# %% [markdown]
# **Step-1: import packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Step-2: Create a Dataframe using List**

# %%
names=['Ramesh','Suresh','Mahesh']
pd.DataFrame(names)
# Out:
#         0
# 0  Ramesh
# 1  Suresh
# 2  Mahesh

# %%
names=['Ramesh','Suresh','Mahesh']
age = [20,21,22]
pd.DataFrame(zip(names,age))
# Out:
#         0   1
# 0  Ramesh  20
# 1  Suresh  21
# 2  Mahesh  22

# %%
names=['Ramesh','Suresh','Mahesh']
age = [20,21,22]
city=['Hyd','Mumbai','Pune']
pd.DataFrame(zip(names,age,city))
# Out:
#         0   1       2
# 0  Ramesh  20     Hyd
# 1  Suresh  21  Mumbai
# 2  Mahesh  22    Pune

# %% [markdown]
# **Step-3: Insert the columns**

# %% [markdown]
# - column value excpect an Index or array-like

# %%
names=['Ramesh','Suresh','Mahesh']
pd.DataFrame(names,columns=['Names'])
# Out:
#     Names
# 0  Ramesh
# 1  Suresh
# 2  Mahesh

# %%
names=['Ramesh','Suresh','Mahesh']
age = [20,21,22]
city=['Hyd','Mumbai','Pune']
cols=['Names','Age','City']
pd.DataFrame(zip(names,age,city),
             columns=cols)
# Out:
#     Names  Age    City
# 0  Ramesh   20     Hyd
# 1  Suresh   21  Mumbai
# 2  Mahesh   22    Pune

# %% [markdown]
# **Step-4: Modify the index**

# %%
names=['Ramesh','Suresh','Mahesh']
age = [20,21,22]
city=['Hyd','Mumbai','Pune']
cols=['Names','Age','City']
idx=['A','B','C']
df1=pd.DataFrame(zip(names,age,city),
             index=idx,
            columns=cols)

# %%
df1
# Out:
#     Names  Age    City
# A  Ramesh   20     Hyd
# B  Suresh   21  Mumbai
# C  Mahesh   22    Pune

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# - index length should be match with number of rows
#
# - columns length should be match with number of cols

# %% [markdown]
# **Step-5: Create a Dataframe using Dictionary**

# %%
d={'Names':['Ramesh','Suresh','Mahesh'],
  'Age':[20,21,22],
  'City':['Hyd','Mumbai','Pune']}
pd.DataFrame(d)

# keys behave as column names
# no need of explitly mention
# Out:
#     Names  Age    City
# 0  Ramesh   20     Hyd
# 1  Suresh   21  Mumbai
# 2  Mahesh   22    Pune

# %% [markdown]
# **Step-6: Create a DataFrame using Scalar values means with out list**

# %%
d={'Names':'Ramesh',
  'Age':20,
  'City':'Hyd'}
pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 4
#       1 d={'Names':'Ramesh',
#       2   'Age':20,
#       3   'City':'Hyd'}
# ----> 4 pd.DataFrame(d)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:667, in _extract_index(data)
#     664         raise ValueError("Per-column arrays must each be 1-dimensional")
#     666 if not indexes and not raw_lengths:
# --> 667     raise ValueError("If using all scalar values, you must pass an index")
#     669 if have_series:
#     670     index = union_indexes(indexes)
#
# ValueError: If using all scalar values, you must pass an index

# %%
d={'Names':'Ramesh',
  'Age':20,
  'City':'Hyd'}
pd.DataFrame(d,index=[1,2,3])
# Out:
#     Names  Age City
# 1  Ramesh   20  Hyd
# 2  Ramesh   20  Hyd
# 3  Ramesh   20  Hyd

# %% [markdown]
# **Step-7: Data quick cheks**

# %% [markdown]
# - shape
#
# - size
#
# - len
#
# - columns
#
# - dtypes

# %%
df1
# Out:
#     Names  Age    City
# A  Ramesh   20     Hyd
# B  Suresh   21  Mumbai
# C  Mahesh   22    Pune

# %%
df1.shape
# Out:
# (3, 3)

# %%
df1.size
# Out:
# 9

# %%
len(df1)
# Out:
# 3

# %%
df1.dtypes
# Out:
# Names    object
# Age       int64
# City     object
# dtype: object

# %% [markdown]
# # 23/04/25

# %% [markdown]
# **Step-8: Add data to empty dataframe**

# %%
pd.DataFrame()  # Empty DataFrame because in brackets we nothing provided anything
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
d1=pd.DataFrame()
d1['Names']=['Ramesh','Suresh','Sathish']
d1['Age']=[20,21,22]
d1
# Out:
#      Names  Age
# 0   Ramesh   20
# 1   Suresh   21
# 2  Sathish   22

# %% [markdown]
# **Step-9: Add data to already Existed Dataframe**

# %% [markdown]
# - df1 already has a data with columns Names, Age, City
#
# - Now we want to create a new column with Marks

# %%
df1
# Out:
#     Names  Age    City
# A  Ramesh   20     Hyd
# B  Suresh   21  Mumbai
# C  Mahesh   22    Pune

# %%
df1['Marks']=[100,200,300]
df1
# Out:
#     Names  Age    City  Marks
# A  Ramesh   20     Hyd    100
# B  Suresh   21  Mumbai    200
# C  Mahesh   22    Pune    300

# %%
df1
# Out:
#     Names  Age    City  Marks
# A  Ramesh   20     Hyd    100
# B  Suresh   21  Mumbai    200
# C  Mahesh   22    Pune    300

# %% [markdown]
# **Step-10: How to update the column values**

# %% [markdown]
# - If you want to add the new column to empty dataframe
#
# - if you want to add the new column to already existed dataframe
#
# - if you want to modify the data of a specific column
#
# - syntax is same
#
# - df[colname]=[data]

# %%
df1.columns
# Out:
# Index(['Names', 'Age', 'City', 'Marks'], dtype='object')

# %%
df1['City']=['Delhi','Chennai','Hyd']
df1['city']=['Delhi','Chennai','Hyd']
df1
# Out:
#     Names  Age     City  Marks     city
# A  Ramesh   20    Delhi    100    Delhi
# B  Suresh   21  Chennai    200  Chennai
# C  Mahesh   22      Hyd    300      Hyd

# %% [markdown]
# **Step-11: How to Drop the specific column**

# %% [markdown]
# - by default axis=0 represents index
#
# - if you provide the column change axis=1
#
# - inplace=True then Data frame will be overwrite

# %%
df1.drop('city',axis=1,inplace=True)
# by doing shift+tab you get to know that why we mention axis=1
# use inplace=True for saving the latest df1(variable) value

# %%
df1
# Out:
#     Names  Age     City  Marks
# A  Ramesh   20    Delhi    100
# B  Suresh   21  Chennai    200
# C  Mahesh   22      Hyd    300

# %%
df1['age']=[20,30,40]
df1
# Out:
#     Names  Age     City  Marks  age
# A  Ramesh   20    Delhi    100   20
# B  Suresh   21  Chennai    200   30
# C  Mahesh   22      Hyd    300   40

# %%
df1.drop(columns='age',inplace=True)

# %%
df1
# Out:
#     Names  Age     City  Marks
# A  Ramesh   20    Delhi    100
# B  Suresh   21  Chennai    200
# C  Mahesh   22      Hyd    300

# %%
df1['age']=[20,30,40]
df1['city']=['D','C','P']
df1
# Out:
#     Names  Age     City  Marks  age city
# A  Ramesh   20    Delhi    100   20    D
# B  Suresh   21  Chennai    200   30    C
# C  Mahesh   22      Hyd    300   40    P

# %%
df1.drop(['age','city'],axis=1) # multiple means list
# Out:
#     Names  Age     City  Marks
# A  Ramesh   20    Delhi    100
# B  Suresh   21  Chennai    200
# C  Mahesh   22      Hyd    300

# %%
df1.drop(columns=['age','city'])
# Out:
#     Names  Age     City  Marks
# A  Ramesh   20    Delhi    100
# B  Suresh   21  Chennai    200
# C  Mahesh   22      Hyd    300

# %%
df1.drop(index='A')
# Out:
#     Names  Age     City  Marks  age city
# B  Suresh   21  Chennai    200   30    C
# C  Mahesh   22      Hyd    300   40    P

# %%
df1.drop(['A'])
# Out:
#     Names  Age     City  Marks  age city
# B  Suresh   21  Chennai    200   30    C
# C  Mahesh   22      Hyd    300   40    P

# %%
df1.drop(labels=['A'])
# Out:
#     Names  Age     City  Marks  age city
# B  Suresh   21  Chennai    200   30    C
# C  Mahesh   22      Hyd    300   40    P

# %%
df1
# Out:
#     Names  Age     City  Marks  age city
# A  Ramesh   20    Delhi    100   20    D
# B  Suresh   21  Chennai    200   30    C
# C  Mahesh   22      Hyd    300   40    P

# %% [markdown]
# **Step-12: Rename the column**

# %% [markdown]
# - create a dictionary key as old name value as new name

# %%
dict1={'Marks':'marks'}
df1.rename(dict1,axis=1)  # dont do inplace (for columns use axis=1)
# Out:
#     Names  Age     City  marks  age city
# A  Ramesh   20    Delhi    100   20    D
# B  Suresh   21  Chennai    200   30    C
# C  Mahesh   22      Hyd    300   40    P

# %%
df1.rename(columns=dict1)
# Out:
#     Names  Age     City  marks  age city
# A  Ramesh   20    Delhi    100   20    D
# B  Suresh   21  Chennai    200   30    C
# C  Mahesh   22      Hyd    300   40    P

# %%
df1.drop(['age','city'],axis=1,inplace=True)

# %%
df1.columns=['names','age','city','marks']
df1
# Out:
#     names  age     city  marks
# A  Ramesh   20    Delhi    100
# B  Suresh   21  Chennai    200
# C  Mahesh   22      Hyd    300

# %% [markdown]
# **Step-13: Add a new row**

# %%
df1
# Out:
#     names  age     city  marks
# A  Ramesh   20    Delhi    100
# B  Suresh   21  Chennai    200
# C  Mahesh   22      Hyd    300

# %%
df1[<colname>]=[v1,v2,v3]
df1.loc[<index>]=[data]

# %%
df1.loc['D']=['Manish',25,'Patna',400]

# %%
df1
# Out:
#     names  age     city  marks
# A  Ramesh   20    Delhi    100
# B  Suresh   21  Chennai    200
# C  Mahesh   22      Hyd    300
# D  Manish   25    Patna    400

# %% [markdown]
# **Step-14: Save the dataframe**

# %%
df1
# Out:
#     names  age     city  marks
# A  Ramesh   20    Delhi    100
# B  Suresh   21  Chennai    200
# C  Mahesh   22      Hyd    300
# D  Manish   25    Patna    400

# %%
df1.to_csv('data.csv')  # write .to and click tab and select in which format you want to save

# %% [markdown]
# **Step-15: Read the dataframe**

# %%
pd.read_csv('data.csv')
# Out:
#   Unnamed: 0   names  age     city  marks
# 0          A  Ramesh   20    Delhi    100
# 1          B  Suresh   21  Chennai    200
# 2          C  Mahesh   22      Hyd    300
# 3          D  Manish   25    Patna    400

# %%
df1.to_csv('data1.csv',index=False)

# %%
pd.read_csv('data1.csv')
# Out:
#     names  age     city  marks
# 0  Ramesh   20    Delhi    100
# 1  Suresh   21  Chennai    200
# 2  Mahesh   22      Hyd    300
# 3  Manish   25    Patna    400

# %%
df1.to_csv('data1.csv',index=False)   # can you try with excel
pd.read_csv('data1.csv')              # read with excel
# we use index=false for storing the file in folder (either in .csv or .excle format)
# Out:
#     Names  Age     City  Marks  age city
# 0  Ramesh   20    Delhi    100   20    D
# 1  Suresh   21  Chennai    200   30    C
# 2  Mahesh   22      Hyd    300   40    P

# %%
df1.to_excel('data1.xlsx',index=False)   
pd.read_excel('data1.xlsx')
# Out:
#     names  age     city  marks
# 0  Ramesh   20    Delhi    100
# 1  Suresh   21  Chennai    200
# 2  Mahesh   22      Hyd    300
# 3  Manish   25    Patna    400

# %% [markdown]
# **Note by me**
#
# - if the data file is not present in that same folder where we running the python file then just put all the directory location
