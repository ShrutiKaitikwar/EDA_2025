# %% [markdown]
# # 07/05/25

# %%
import numpy as np
import pandas as pd
Data={'Names':['Ramesh','Suresh','Sathish',np.nan],'Age':[np.nan,22,25,27],'City':['Pune','Pune',np.nan,'Hyd']}
df=pd.DataFrame(Data)
df
# Out:
#      Names   Age  City
# 0   Ramesh   NaN  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0   NaN
# 3      NaN  27.0   Hyd

# %%
df.to_csv('data_missing.csv',index=False)

# %%
pd.read_csv('data_missing.csv')
# Out:
#      Names   Age  City
# 0   Ramesh   NaN  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0   NaN
# 3      NaN  27.0   Hyd

# %%
import numpy as np
import pandas as pd
Data1={'Names':['Ramesh','Suresh','Sathish',None],'Age':[None,22,25,27],'City':['Pune','Pune',None,'Hyd']}
df1=pd.DataFrame(Data1)
df1
# Out:
#      Names   Age  City
# 0   Ramesh   NaN  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0  None
# 3     None  27.0   Hyd

# %%
df1.to_csv('data_missing1.csv',index=False)

# %%
df.dtypes
# Out:
# Names     object
# Age      float64
# City      object
# dtype: object

# %%
df1.dtypes
# Out:
# Names     object
# Age      float64
# City      object
# dtype: object

# %% [markdown]
# **isnull**

# %%
df.isnull()
# Out:
#    Names    Age   City
# 0  False   True  False
# 1  False  False  False
# 2  False  False   True
# 3   True  False  False

# %%
df1.isnull()
# Out:
#    Names    Age   City
# 0  False   True  False
# 1  False  False  False
# 2  False  False   True
# 3   True  False  False

# %%
df.isnull().sum()
# Out:
# Names    1
# Age      1
# City     1
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# Names    1
# Age      1
# City     1
# dtype: int64

# %% [markdown]
# **fillna**

# %%
df.fillna(30)  # Not Recomended
# Out:
#      Names   Age  City
# 0   Ramesh  30.0  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0    30
# 3       30  27.0   Hyd

# %%
df1.fillna(30)
# Out:
#      Names   Age  City
# 0   Ramesh  30.0  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0    30
# 3       30  27.0   Hyd

# %% [markdown]
# - the above one is we are filling randomly
#
# - all the columns are filled with random number
#
# - It is not a good approach because in a data we have different data types

# %%
df.fillna('Hyd')
# Out:
#      Names   Age  City
# 0   Ramesh   Hyd  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0   Hyd
# 3      Hyd  27.0   Hyd

# %%
df1.fillna('Hyd')
# Out:
#      Names   Age  City
# 0   Ramesh   Hyd  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0   Hyd
# 3      Hyd  27.0   Hyd

# %% [markdown]
# **What is the difference between np.nan and None**

# %%
np.nan+5
# Out:
# nan

# %%
None+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 None+5
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
arr1=np.array([1,2,np.nan,3])
arr2=np.array([1,2,None,3])

# %%
arr1
# Out:
# array([ 1.,  2., nan,  3.])

# %%
arr2
# Out:
# array([1, 2, None, 3], dtype=object)

# %%
np.nansum(arr1),np.sum(arr1)
# Out:
# (6.0, nan)

# %%
np.sum(arr2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 np.sum(arr2)
#
# File ~\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:2313, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2310         return out
#    2311     return res
# -> 2313 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2314                       initial=initial, where=where)
#
# File ~\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %% [markdown]
# - np.nan represents **float type**
#
# - None represents **Object type**
#
# - if data operations related to Maths then nan format is better

# %% [markdown]
# **Fill the value based on column**

# %%
# df.fillna()
df['Names'].fillna('Manish')
# Out:
# 0     Ramesh
# 1     Suresh
# 2    Sathish
# 3     Manish
# Name: Names, dtype: object

# %%
df
# Out:
#      Names   Age  City
# 0   Ramesh   NaN  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0   NaN
# 3      NaN  27.0   Hyd

# %%
df['Age'].fillna(20)
# Out:
# 0    20.0
# 1    22.0
# 2    25.0
# 3    27.0
# Name: Age, dtype: float64

# %%
df['Age'].fillna('20')
# Out:
# 0      20
# 1    22.0
# 2    25.0
# 3    27.0
# Name: Age, dtype: object

# %%
df['Age'].fillna(20).values
# Out:
# array([20., 22., 25., 27.])

# %%
df['Age'].fillna('20').values
# Out:
# array(['20', 22.0, 25.0, 27.0], dtype=object)

# %%
df['Age1']=df['Age'].fillna(20).values
df['Age2']=df['Age'].fillna('20').values

# %%
df
# Out:
#      Names   Age  City  Age1  Age2
# 0   Ramesh   NaN  Pune  20.0    20
# 1   Suresh  22.0  Pune  22.0  22.0
# 2  Sathish  25.0   NaN  25.0  25.0
# 3      NaN  27.0   Hyd  27.0  27.0

# %%
df.dtypes
# Out:
# Names     object
# Age      float64
# City      object
# Age1     float64
# Age2      object
# dtype: object

# %% [markdown]
# - because of one value total data type is changed
#
# - we can convert one data type column to another data type **astype**

# %%
df['Age2']=df['Age2'].astype('float')

# %%
df.dtypes
# Out:
# Names     object
# Age      float64
# City      object
# Age1     float64
# Age2     float64
# dtype: object

# %% [markdown]
# **Fill with Method**

# %%
import numpy as np
import pandas as pd
Data={'Names':['Ramesh','Suresh','Sathish',np.nan],'Age':[np.nan,22,25,27],'City':['Pune','Pune',np.nan,'Hyd']}
df=pd.DataFrame(Data)
df
# Out:
#      Names   Age  City
# 0   Ramesh   NaN  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0   NaN
# 3      NaN  27.0   Hyd

# %% [markdown]
# - pad
#
# - bfill
#
# - ffill
#
# - backfill

# %%
df.fillna(method='pad')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9100\196241153.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='pad')
#      Names   Age  City
# 0   Ramesh   NaN  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0  Pune
# 3  Sathish  27.0   Hyd

# %%
import warnings
warnings .filterwarnings('ignore')
df.fillna(method='pad')
# Out:
#      Names   Age  City
# 0   Ramesh   NaN  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0  Pune
# 3  Sathish  27.0   Hyd

# %%
df
# Out:
#      Names   Age  City
# 0   Ramesh   NaN  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0   NaN
# 3      NaN  27.0   Hyd

# %%
s='U+200B (ZERO WIDTH SPACE)'
s1=''
for i in s:
    if i.isdigit():
        s1=s1+i
int(s1)
# Out:
# 200

# %%
import warnings
warnings .filterwarnings('ignore')
df.fillna(method='bfill')
# Out:
#      Names   Age  City
# 0   Ramesh  22.0  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0   Hyd
# 3      NaN  27.0   Hyd

# %%
import warnings
warnings .filterwarnings('ignore')
df.fillna(method='ffill')
# Out:
#      Names   Age  City
# 0   Ramesh   NaN  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0  Pune
# 3  Sathish  27.0   Hyd

# %%
import warnings
warnings .filterwarnings('ignore')
df.fillna(method='backfill')
# Out:
#      Names   Age  City
# 0   Ramesh  22.0  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0   Hyd
# 3      NaN  27.0   Hyd

# %%
df.fillna(method='pad',axis=1)
# Out:
#      Names     Age  City
# 0   Ramesh  Ramesh  Pune
# 1   Suresh    22.0  Pune
# 2  Sathish    25.0  25.0
# 3      NaN    27.0   Hyd

# %%
# pad-ffill
# bfill-backfill

# %% [markdown]
# **Mean-Median-Mode**
#
# - insted of filling with random values
#
# - we can use mean median and mode also
#
# - For Numerical columns use mean and Median
#
#     - if Data outliers are there use **Median**
#
# - For categorical columns use **Mode**

# %%
# First calculate median
# Then fill with median
age_median=df['Age'].median()
df['Age'].fillna(age_median)
# Out:
# 0    25.0
# 1    22.0
# 2    25.0
# 3    27.0
# Name: Age, dtype: float64

# %%
round(df['Age'].mean(),2)
# Out:
# 24.67

# %% [markdown]
# **KNNImputer**

# %% [markdown]
# - KNN: K nearest neigbours
#
# - instead of taking all the data values average
#
# - we can take only specific values average
#
# - thats why the name is called as Nearest Neighbours
#
# - Hyper parameter: the argument which user can provide
#
# - here k is hyper parameter
#
# - which means the user can decide how many neighbours he can choose
#
# - it is under sklearn
#
#     - class name imputer
#
#         - method name KNNImputer

# %%
data1={'A':[1,2,3,4,5,np.nan,7],'B':[11,22,np.nan,47,55,77,7],'C':[21,10,3,4,np.nan,66,7]}
df2=pd.DataFrame(data1)

# %%
from sklearn.impute import KNNImputer
knn=KNNImputer(n_neighbors=2)
knn.fit_transform(df2)
# Out:
# array([[ 1. , 11. , 21. ],
#        [ 2. , 22. , 10. ],
#        [ 3. , 51. ,  3. ],
#        [ 4. , 47. ,  4. ],
#        [ 5. , 55. ,  3.5],
#        [ 4.5, 77. , 66. ],
#        [ 7. ,  7. ,  7. ]])

# %%
(4+5+7)/3
# Out:
# 5.333333333333333

# %%
(1+2+7)/3
# Out:
# 3.3333333333333335

# %% [markdown]
# - How it is deciding neigbours: Euclidian distance
#
# - give the categorical data : It is works or not

# %%
10days individual
1day 2hours
bullets
wed sql
transforamtions

# %% [markdown]
# # 08/05/25

# %%
idea-1: filling with random value = df.fillname(<random value)
idea-2: filling with rv based on column = df[<col>].fillname(<rv>)
idea-3: filling with some pattern using a method: df.fillna(<method>)
idea-4: filling with m-m-m based on column = df[<col>].fillname(<m>or<m>or<m>)
idea-5: filling with average value only selected neighbours
idea-6: filling with a value based on correlation with another columns

# %% [markdown]
# **Mean-Median-Mode**

# %%
Data1=pd.DataFrame({'Names':['Ramesh','Suresh','Sathish',None],'Age':[None,22,25,27],'City':['Pune','Pune',None,'Hyd']})
age_mean=Data1['Age'].mean()
print('age_mean:',age_mean)
Data1['Age'].fillna(age_mean)
Data1
# Out:
# age_mean: 24.666666666666668
#      Names   Age  City
# 0   Ramesh   NaN  Pune
# 1   Suresh  22.0  Pune
# 2  Sathish  25.0  None
# 3     None  27.0   Hyd

# %%
city_mode=Data1['City'].mode()
Data1['City'].fillna(city_mode)
# Out:
# 0    Pune
# 1    Pune
# 2     NaN
# 3     Hyd
# Name: City, dtype: object

# %%
age_mean
# Out:
# 24.666666666666668

# %%
city_mode
# Out:
# 0    Pune
# Name: City, dtype: object

# %%
city_mode.values[0]
# Out:
# 'Pune'

# %% [markdown]
# - in future sometimes if we direct imput mode value we will get error
#
# - mode is coming as series
#
# - mean is coming as fixed values
#
# - so first convert series to fixed value then apply it

# %% [markdown]
# **impute class**

# %% [markdown]
# - under sklearn we have impute class is there

# %%
from sklearn import impute

# %%
dir(impute)
# Out:
# ['KNNImputer',
#  'MissingIndicator',
#  'SimpleImputer',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_base',
#  '_knn',
#  'typing']

# %% [markdown]
# **KNN Immputer**

# %% [markdown]
# - k-Nearest Neighbours
#
# - Where k = hyper parameter which means the user can change
#
# - Idea: Instead of taking all the samples average
#
#     - First fix the neighbours number i.e. k
#
#     - Then find the neighbours using distance metric
#
#     - Then take the average of those samples to fill the missing value

# %%
import numpy as np
from sklearn.impute import KNNImputer
X=[[1,2,np.nan],[3,np.nan,3],[np.nan,60,5],[8,8,7]]
pd.DataFrame(X)
# Out:
#      0     1    2
# 0  1.0   2.0  NaN
# 1  3.0   NaN  3.0
# 2  NaN  60.0  5.0
# 3  8.0   8.0  7.0

# %%
import numpy as np
from sklearn.impute import KNNImputer
X=[[1,2,np.nan],[3,np.nan,3],[np.nan,60,5],[8,8,7]]
imputer=KNNImputer(n_neighbors=2,weights='distance')
imputer.fit_transform(X)
# Out:
# array([[ 1.        ,  2.        ,  3.93905505],
#        [ 3.        , 31.        ,  3.        ],
#        [ 3.25775362, 60.        ,  5.        ],
#        [ 8.        ,  8.        ,  7.        ]])

# %% [markdown]
# - weights = 'uniform'
#
# - uniform: equal priority to every one
#
# - sklearn = class
#
# - prepocessing/impute = method

# %%
import numpy as np
from sklearn.impute import KNNImputer
X=[[1,2,np.nan],[3,np.nan,3],[np.nan,60,5],[8,8,7]]
imputer=KNNImputer(n_neighbors=2)
imputer.fit_transform(X)
# Out:
# array([[ 1. ,  2. ,  5. ],
#        [ 3. , 31. ,  3. ],
#        [ 5.5, 60. ,  5. ],
#        [ 8. ,  8. ,  7. ]])
